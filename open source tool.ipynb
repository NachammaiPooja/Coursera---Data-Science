# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# NAME : **S.Nachammai Devi Pooja**
# DESIRED OCCUPATION : DATA SCIENTIST

# %% [markdown]
# _I like to analyze data.In data science we are not only understanding the data, but we also get to make predictions based on the data.It also helps us to make informed decisions and to stop guessing._

# %% [markdown]
# ### Python Program to Count the Number of Each Vowel :
# ============================================================
# ### In this program, you'll learn to count the number of each vowel in a string using dictionary and list comprehension.

# %%
#CODE :

# string of vowels
vowels = 'aeiou'

ip_str = 'Hello, This is program to count the number of vowels'

# make it suitable for caseless comparisions
ip_str = ip_str.casefold()

# make a dictionary with each vowel a key and value 0
count = {}.fromkeys(vowels,0)

# count the vowels
for char in ip_str:
   if char in count:
       count[char] += 1

print(count)
# Out:
# {'a': 1, 'e': 4, 'i': 2, 'o': 6, 'u': 2}

# %% [markdown]
# #### If you choose to build a career in data science, you could choose from a wide range of jobs such as:
#
# - Data Scientist.
# - Data Analyst.
# - Data Architect.
# - Data Engineer.
# - Statistician.
# - Database Administrator.
# - Business Analyst.
# ---

# %% [markdown]
# ### The four types of data analysis are:
# 1. Descriptive Analysis
# 2. Diagnostic Analysis
# 3. Predictive Analysis
# 4. Prescriptive Analysis
# ___

# %% [markdown]
# ### A Table showing a college record :
# ***

# %% [markdown]
# NAME | AGE | DEPT
# --- | --- | ---
# *Stella* | 20 | **CSE**
# *Pooja*  | 18 | **ECE**
# *Swetha* | 19 | **EEE**

# %% [markdown]
# ### PUPPIES

# %% [markdown]
# ![puppies.jpg](attachment:puppies.jpg)
